# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/'My Drive'/action_recognition/computervision-recipes/contrib/action_recognition/r2p1d
# Out:
# /content/drive/My Drive/action_recognition/computervision-recipes/contrib/action_recognition/r2p1d

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !pip install decord
# Out:
# Requirement already satisfied: decord in /usr/local/lib/python3.6/dist-packages (0.3.9)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from decord) (1.18.5)

# %%
# !pip install einops
# Out:
# Requirement already satisfied: einops in /usr/local/lib/python3.6/dist-packages (0.2.0)

# %%
import os
import time
import sys

import numpy as np
from sklearn.metrics import accuracy_score
import torch
import torch.cuda as cuda
import torch.nn as nn
import torchvision

from vu.data import show_batch, VideoDataset
from vu.models.r2plus1d import R2Plus1D 
from vu.utils import system_info

system_info()
# Out:
# 3.6.9 (default, Apr 18 2020, 01:56:04)
# [GCC 8.4.0]
#
# PyTorch 1.5.0+cu101
#
# Torch-vision 0.6.0+cu101
#
# Available devices:
# 0: Tesla P100-PCIE-16GB

# %% [markdown]
# #**Model configurations**

# %%
DATA_ROOT = os.path.join("data", "afl")
VIDEO_DIR = os.path.join(DATA_ROOT, "videos")
TRAIN_SPLIT = os.path.join(DATA_ROOT, "afl_vid_train_split.txt")
TEST_SPLIT = os.path.join(DATA_ROOT, "afl_vid_val_split.txt")

# %%
MODEL_INPUT_SIZE = 32
BATCH_SIZE = 4

r2plus1d_cfgs = dict(
    num_classes=4,
    video_dir=VIDEO_DIR,
    train_split=TRAIN_SPLIT,
    valid_split=TEST_SPLIT,
    base_model='ig65m',
    sample_length=MODEL_INPUT_SIZE,     
    sample_step=1,       
    im_scale=128,         
    mean=(0.43216, 0.394666, 0.37645),
    std=(0.22803, 0.22145, 0.216989),
    random_shift=True,
    temporal_jitter_step=2,   
    flip_ratio=0.5,
    random_crop=True,
    video_ext='mp4',
)

train_cfgs = dict(
    mixed_prec=False,
    batch_size=BATCH_SIZE,
    grad_steps=2,
    lr=0.001,        
    momentum=0.95,
    warmup_pct=0.3,  
    lr_decay_factor=0.001,
    weight_decay=0.0001,
    epochs=48, 
    model_name='afl',
    model_dir=os.path.join("checkpoints", "ig65m_afl"),
)

# %%
learn = R2Plus1D(r2plus1d_cfgs)
# Out:
# Loading r2plus1d_34_32_ig65m model
# Using cache found in /root/.cache/torch/hub/moabitcoin_ig65m-pytorch_master

# %%
learn.model
# Out:
# VideoResNet(
#   (stem): R2Plus1dStem(
#     (0): Conv3d(3, 45, kernel_size=(1, 7, 7), stride=(1, 2, 2), padding=(0, 3, 3), bias=False)
#     (1): BatchNorm3d(45, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv3d(45, 64, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#     (4): BatchNorm3d(64, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#   )
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(64, 144, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(144, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(144, 64, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(64, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(64, 144, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(144, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(144, 64, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(64, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (1): BasicBlock(
#       (conv1): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(64, 144, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(144, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(144, 64, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(64, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(64, 144, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(144, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(144, 64, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(64, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (2): BasicBlock(
#       (conv1): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(64, 144, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(144, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(144, 64, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(64, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(64, 144, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(144, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(144, 64, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(64, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(64, 230, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(230, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(230, 128, kernel_size=(3, 1, 1), stride=(2, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(128, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(128, 288, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(288, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(288, 128, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(128, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv3d(64, 128, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False)
#         (1): BatchNorm3d(128, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(128, 288, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(288, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(288, 128, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(128, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(128, 288, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(288, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(288, 128, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(128, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (2): BasicBlock(
#       (conv1): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(128, 288, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(288, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(288, 128, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(128, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(128, 288, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(288, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(288, 128, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(128, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (3): BasicBlock(
#       (conv1): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(128, 288, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(288, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(288, 128, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(128, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(128, 288, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(288, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(288, 128, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(128, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(128, 460, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(460, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(460, 256, kernel_size=(3, 1, 1), stride=(2, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(256, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(256, 576, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(576, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(576, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(256, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv3d(128, 256, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False)
#         (1): BatchNorm3d(256, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(256, 576, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(576, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(576, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(256, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(256, 576, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(576, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(576, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(256, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (2): BasicBlock(
#       (conv1): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(256, 576, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(576, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(576, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(256, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(256, 576, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(576, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(576, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(256, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (3): BasicBlock(
#       (conv1): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(256, 576, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(576, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(576, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(256, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(256, 576, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(576, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(576, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(256, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (4): BasicBlock(
#       (conv1): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(256, 576, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(576, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(576, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(256, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(256, 576, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(576, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(576, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(256, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (5): BasicBlock(
#       (conv1): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(256, 576, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(576, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(576, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(256, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(256, 576, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(576, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(576, 256, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(256, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(256, 921, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(921, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(921, 512, kernel_size=(3, 1, 1), stride=(2, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(512, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(512, 1152, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(1152, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(1152, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(512, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(2, 2, 2), bias=False)
#         (1): BatchNorm3d(512, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(512, 1152, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(1152, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(1152, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(512, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(512, 1152, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(1152, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(1152, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(512, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#     (2): BasicBlock(
#       (conv1): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(512, 1152, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(1152, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(1152, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(512, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#       )
#       (conv2): Sequential(
#         (0): Conv2Plus1D(
#           (0): Conv3d(512, 1152, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#           (1): BatchNorm3d(1152, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#           (2): ReLU(inplace=True)
#           (3): Conv3d(1152, 512, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#         )
#         (1): BatchNorm3d(512, eps=0.001, momentum=0.9, affine=True, track_running_stats=True)
#       )
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool3d(output_size=(1, 1, 1))
#   (fc): Linear(in_features=512, out_features=4, bias=True)
# )

# %%
learn.show_batch(num_samples=3)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# #**Train model**

# %%
learn.fit(train_cfgs)
# Out:
# Params to learn:
# 	full network
# Epoch 1 ==========
# lr=[3.9999999999999996e-05]
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:1206: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   "please use `get_last_lr()`.", UserWarning)
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2973: UserWarning: Default upsampling behavior when mode=bilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# train took 72.63 sec: loss = 1.4304, top1_acc = 30.9524, top5_acc = 73.8095
# valid took 20.65 sec: loss = 1.4532, top1_acc = 22.2222, top5_acc = 72.2222
# Epoch 2 ==========
# lr=[5.313140544408986e-05]
# train took 43.82 sec: loss = 1.3948, top1_acc = 33.3333, top5_acc = 80.9524
# valid took 21.02 sec: loss = 1.4294, top1_acc = 22.2222, top5_acc = 72.2222
# Epoch 3 ==========
# lr=[9.180714757245454e-05]
# train took 43.76 sec: loss = 1.3399, top1_acc = 40.4762, top5_acc = 78.5714
# valid took 20.69 sec: loss = 1.3586, top1_acc = 33.3333, top5_acc = 77.7778
# Epoch 4 ==========
# lr=[0.00015391111450701667]
# train took 42.94 sec: loss = 1.2324, top1_acc = 50.0000, top5_acc = 80.9524
# valid took 20.41 sec: loss = 1.2450, top1_acc = 50.0000, top5_acc = 94.4444
# Epoch 5 ==========
# lr=[0.00023604533804150933]
# train took 48.05 sec: loss = 1.0775, top1_acc = 73.8095, top5_acc = 92.8571
# valid took 20.40 sec: loss = 1.0166, top1_acc = 55.5556, top5_acc = 88.8889
# Epoch 6 ==========
# lr=[0.0003337159107173202]
# train took 45.60 sec: loss = 0.9669, top1_acc = 78.5714, top5_acc = 100.0000
# valid took 20.35 sec: loss = 0.9653, top1_acc = 66.6667, top5_acc = 100.0000
# Epoch 7 ==========
# lr=[0.0004415788663271056]
# train took 42.72 sec: loss = 0.9875, top1_acc = 61.9048, top5_acc = 97.6190
# valid took 20.38 sec: loss = 0.8223, top1_acc = 66.6667, top5_acc = 94.4444
# Epoch 8 ==========
# lr=[0.0005537325706937407]
# train took 42.23 sec: loss = 0.7419, top1_acc = 78.5714, top5_acc = 97.6190
# valid took 20.16 sec: loss = 0.8613, top1_acc = 72.2222, top5_acc = 94.4444
# Epoch 9 ==========
# lr=[0.0006640406248001635]
# train took 43.06 sec: loss = 0.8112, top1_acc = 71.4286, top5_acc = 95.2381
# valid took 20.45 sec: loss = 0.7754, top1_acc = 77.7778, top5_acc = 100.0000
# Epoch 10 ==========
# lr=[0.0007664676128871242]
# train took 44.07 sec: loss = 0.5761, top1_acc = 83.3333, top5_acc = 97.6190
# valid took 20.38 sec: loss = 0.8711, top1_acc = 61.1111, top5_acc = 94.4444
# Epoch 11 ==========
# lr=[0.000855409325333844]
# train took 41.99 sec: loss = 0.5306, top1_acc = 83.3333, top5_acc = 100.0000
# valid took 20.26 sec: loss = 0.9836, top1_acc = 77.7778, top5_acc = 94.4444
# Epoch 12 ==========
# lr=[0.0009259993884443668]
# train took 44.82 sec: loss = 0.3673, top1_acc = 92.8571, top5_acc = 95.2381
# valid took 20.24 sec: loss = 1.6875, top1_acc = 66.6667, top5_acc = 88.8889
# Epoch 13 ==========
# lr=[0.0009743755241394084]
# train took 40.89 sec: loss = 0.2499, top1_acc = 100.0000, top5_acc = 100.0000
# valid took 20.29 sec: loss = 0.8941, top1_acc = 77.7778, top5_acc = 94.4444
# Epoch 14 ==========
# lr=[0.000997890871370511]
# train took 43.55 sec: loss = 0.4067, top1_acc = 88.0952, top5_acc = 97.6190
# valid took 20.19 sec: loss = 1.1803, top1_acc = 61.1111, top5_acc = 94.4444
# Epoch 15 ==========
# lr=[0.000999213438972608]
# train took 42.93 sec: loss = 0.3144, top1_acc = 90.4762, top5_acc = 100.0000
# valid took 20.34 sec: loss = 1.1219, top1_acc = 66.6667, top5_acc = 94.4444
# Epoch 16 ==========
# lr=[0.0009944156364960397]
# train took 43.95 sec: loss = 0.2928, top1_acc = 90.4762, top5_acc = 100.0000
# valid took 20.22 sec: loss = 1.2003, top1_acc = 72.2222, top5_acc = 88.8889
# Epoch 17 ==========
# lr=[0.0009852988717953465]
# train took 41.70 sec: loss = 0.2656, top1_acc = 97.6190, top5_acc = 97.6190
# valid took 20.37 sec: loss = 0.8715, top1_acc = 50.0000, top5_acc = 100.0000
# Epoch 18 ==========
# lr=[0.0009719427874875776]
# train took 43.48 sec: loss = 0.2280, top1_acc = 95.2381, top5_acc = 100.0000
# valid took 20.37 sec: loss = 1.1786, top1_acc = 61.1111, top5_acc = 88.8889
# Epoch 19 ==========
# lr=[0.0009544640602165572]
# train took 42.95 sec: loss = 0.1394, top1_acc = 97.6190, top5_acc = 100.0000
# valid took 20.44 sec: loss = 0.4905, top1_acc = 83.3333, top5_acc = 100.0000
# Epoch 20 ==========
# lr=[0.0009330153813841436]
# train took 43.46 sec: loss = 0.2258, top1_acc = 92.8571, top5_acc = 97.6190
# valid took 20.42 sec: loss = 1.4775, top1_acc = 61.1111, top5_acc = 88.8889
# Epoch 21 ==========
# lr=[0.0009077841232622509]
# train took 44.26 sec: loss = 0.2112, top1_acc = 95.2381, top5_acc = 100.0000
# valid took 20.37 sec: loss = 2.0486, top1_acc = 61.1111, top5_acc = 77.7778
# Epoch 22 ==========
# lr=[0.0008789907021382636]
# train took 43.18 sec: loss = 0.2428, top1_acc = 90.4762, top5_acc = 97.6190
# valid took 20.35 sec: loss = 1.5349, top1_acc = 66.6667, top5_acc = 77.7778
# Epoch 23 ==========
# lr=[0.0008468866527931503]
# train took 46.91 sec: loss = 0.2949, top1_acc = 90.4762, top5_acc = 100.0000
# valid took 20.30 sec: loss = 1.1015, top1_acc = 66.6667, top5_acc = 94.4444
# Epoch 24 ==========
# lr=[0.0008117524311333296]
# train took 45.52 sec: loss = 0.1505, top1_acc = 97.6190, top5_acc = 100.0000
# valid took 20.33 sec: loss = 1.6670, top1_acc = 61.1111, top5_acc = 94.4444
# Epoch 25 ==========
# lr=[0.0007738949641721512]
# train took 42.93 sec: loss = 0.1761, top1_acc = 95.2381, top5_acc = 100.0000
# valid took 20.33 sec: loss = 2.1526, top1_acc = 61.1111, top5_acc = 88.8889
# Epoch 26 ==========
# lr=[0.0007336449687639655]
# train took 42.71 sec: loss = 0.2074, top1_acc = 95.2381, top5_acc = 100.0000
# valid took 20.43 sec: loss = 2.7747, top1_acc = 50.0000, top5_acc = 77.7778
# Epoch 27 ==========
# lr=[0.0006913540625138976]
# train took 43.38 sec: loss = 0.1716, top1_acc = 97.6190, top5_acc = 100.0000
# valid took 20.42 sec: loss = 1.9488, top1_acc = 72.2222, top5_acc = 94.4444
# Epoch 28 ==========
# lr=[0.0006473916921019639]
# train took 42.10 sec: loss = 0.2507, top1_acc = 90.4762, top5_acc = 100.0000
# valid took 20.33 sec: loss = 2.3069, top1_acc = 72.2222, top5_acc = 77.7778
# Epoch 29 ==========
# lr=[0.0006021419058552044]
# train took 42.95 sec: loss = 0.2645, top1_acc = 92.8571, top5_acc = 97.6190
# valid took 20.25 sec: loss = 2.0414, top1_acc = 72.2222, top5_acc = 77.7778
# Epoch 30 ==========
# lr=[0.0005559999987621319]
# train took 43.06 sec: loss = 0.0738, top1_acc = 100.0000, top5_acc = 100.0000
# valid took 20.26 sec: loss = 0.9537, top1_acc = 72.2222, top5_acc = 94.4444
# Epoch 31 ==========
# lr=[0.0005093690592381225]
# train took 49.12 sec: loss = 0.1520, top1_acc = 97.6190, top5_acc = 100.0000
# valid took 20.35 sec: loss = 1.6810, top1_acc = 55.5556, top5_acc = 88.8889
# Epoch 32 ==========
# lr=[0.0004626564478086596]
# train took 41.67 sec: loss = 0.0957, top1_acc = 100.0000, top5_acc = 100.0000
# valid took 20.21 sec: loss = 1.6478, top1_acc = 61.1111, top5_acc = 94.4444
# Epoch 33 ==========
# lr=[0.0004162702384720979]
# train took 41.20 sec: loss = 0.1107, top1_acc = 100.0000, top5_acc = 100.0000
# valid took 20.46 sec: loss = 1.2377, top1_acc = 66.6667, top5_acc = 94.4444
# Epoch 34 ==========
# lr=[0.0003706156538296416]
# train took 43.15 sec: loss = 0.0790, top1_acc = 100.0000, top5_acc = 100.0000
# valid took 20.29 sec: loss = 1.0649, top1_acc = 72.2222, top5_acc = 94.4444
# Epoch 35 ==========
# lr=[0.00032609152512467804]
# train took 43.93 sec: loss = 0.0882, top1_acc = 100.0000, top5_acc = 100.0000
# valid took 20.33 sec: loss = 1.7667, top1_acc = 61.1111, top5_acc = 94.4444
# Epoch 36 ==========
# lr=[0.0002830868081160033]
# train took 44.31 sec: loss = 0.0831, top1_acc = 100.0000, top5_acc = 100.0000
# valid took 20.32 sec: loss = 0.9303, top1_acc = 72.2222, top5_acc = 100.0000
# Epoch 37 ==========
# lr=[0.0002419771852217228]
# train took 42.97 sec: loss = 0.0798, top1_acc = 100.0000, top5_acc = 100.0000
# valid took 20.35 sec: loss = 1.6588, top1_acc = 55.5556, top5_acc = 94.4444
# Epoch 38 ==========
# lr=[0.00020312178361696058]
# train took 43.14 sec: loss = 0.1970, top1_acc = 90.4762, top5_acc = 100.0000
# valid took 20.49 sec: loss = 1.5200, top1_acc = 72.2222, top5_acc = 94.4444
# Epoch 39 ==========
# lr=[0.00016686003795555708]
# train took 43.27 sec: loss = 0.0432, top1_acc = 100.0000, top5_acc = 100.0000
# valid took 20.83 sec: loss = 1.1494, top1_acc = 77.7778, top5_acc = 94.4444
# Epoch 40 ==========
# lr=[0.00013350872512252356]
# train took 43.75 sec: loss = 0.0643, top1_acc = 100.0000, top5_acc = 100.0000
# valid took 20.56 sec: loss = 2.5516, top1_acc = 72.2222, top5_acc = 83.3333
# Epoch 41 ==========
# lr=[0.00010335919692118831]
# train took 43.99 sec: loss = 0.0572, top1_acc = 100.0000, top5_acc = 100.0000
# valid took 20.48 sec: loss = 2.4206, top1_acc = 72.2222, top5_acc = 88.8889
# Epoch 42 ==========
# lr=[7.667483486984251e-05]
# train took 44.30 sec: loss = 0.0366, top1_acc = 100.0000, top5_acc = 100.0000
# valid took 20.48 sec: loss = 2.3749, top1_acc = 61.1111, top5_acc = 88.8889
# Epoch 43 ==========
# lr=[5.3688749342379215e-05]
# train took 44.55 sec: loss = 0.1549, top1_acc = 95.2381, top5_acc = 100.0000
# valid took 20.52 sec: loss = 2.7881, top1_acc = 72.2222, top5_acc = 77.7778
# Epoch 44 ==========
# lr=[3.4601743152870814e-05]
# train took 43.21 sec: loss = 0.0704, top1_acc = 100.0000, top5_acc = 100.0000
# valid took 20.52 sec: loss = 0.6961, top1_acc = 72.2222, top5_acc = 100.0000
# Epoch 45 ==========
# lr=[1.9580557373889158e-05]
# train took 43.75 sec: loss = 0.0954, top1_acc = 100.0000, top5_acc = 100.0000
# valid took 20.48 sec: loss = 1.0402, top1_acc = 72.2222, top5_acc = 100.0000
# Epoch 46 ==========
# lr=[8.756414712820529e-06]
# train took 42.23 sec: loss = 0.1495, top1_acc = 97.6190, top5_acc = 97.6190
# valid took 20.43 sec: loss = 0.7189, top1_acc = 77.7778, top5_acc = 100.0000
# Epoch 47 ==========
# lr=[2.2238731710119163e-06]
# train took 45.91 sec: loss = 0.1836, top1_acc = 95.2381, top5_acc = 100.0000
# valid took 20.40 sec: loss = 0.7018, top1_acc = 66.6667, top5_acc = 100.0000
# Epoch 48 ==========
# lr=[4e-08]
# train took 45.11 sec: loss = 0.0922, top1_acc = 97.6190, top5_acc = 100.0000
# valid took 20.42 sec: loss = 2.2546, top1_acc = 66.6667, top5_acc = 77.7778

# %%
learn.load("afl" + "_046", "checkpoints/ig65m_afl")

# %% [markdown]
# # **Testing**

# %%
device = torch.device("cuda")

# %%
num_segments = 10
test_ds = VideoDataset(
    split_file=r2plus1d_cfgs['valid_split'],
    video_dir=r2plus1d_cfgs['video_dir'],
    num_segments=num_segments,
    sample_length=r2plus1d_cfgs['sample_length'],
    sample_step=1,
    input_size=112,
    im_scale=r2plus1d_cfgs['im_scale'],
    resize_keep_ratio=True,
    mean=r2plus1d_cfgs['mean'],
    std=r2plus1d_cfgs['std'],
    random_shift=False,
    temporal_jitter=False,
    flip_ratio=0.0,
    random_crop=False,
    random_crop_scales=None,
    video_ext=r2plus1d_cfgs['video_ext'],
)

# %%
show_batch(
    test_ds[0][0],
    r2plus1d_cfgs['sample_length'],
    r2plus1d_cfgs['mean'],
    r2plus1d_cfgs['std']
)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
model = learn.model
model.to(device)

model.eval()
infer_times = []
video_preds = []
video_trues = []
clip_preds = []
clip_trues = []

report_every = 100
with torch.no_grad():
    for i, (inputs, label) in enumerate(test_ds, start=1):
        if i % report_every == 0:
            print("{} samples have processed".format(i))
        
        inputs = inputs.to(device, non_blocking=True)
        
        start_time = time.time()
        outputs = model(inputs)
        infer_time = time.time() - start_time
        
        outputs = outputs.cpu().numpy()
        
        infer_times.append(infer_time)
        video_preds.append(outputs.sum(axis=0).argmax())
        video_trues.append(label)
        clip_preds.extend(outputs.argmax(axis=1))
        clip_trues.extend([label] * num_segments)
        
print("Done! {} samples have processed".format(len(test_ds)))

print("Avg. inference time per video (10 clips) =", np.array(infer_times).mean() * 1000, "ms")
print("Video prediction accuracy =", accuracy_score(video_trues, video_preds))
print("Clip prediction accuracy =", accuracy_score(clip_trues, clip_preds))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2854: UserWarning: The default behavior for interpolate/upsample with float scale_factor will change in 1.6.0 to align with other frameworks/libraries, and use scale_factor directly, instead of relying on the computed output size. If you wish to keep the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor will change "
# Done! 18 samples have processed
# Avg. inference time per video (10 clips) = 8.222050136990019 ms
# Video prediction accuracy = 0.8888888888888888
# Clip prediction accuracy = 0.8388888888888889
